# %% [markdown]
# # PTT 網路爬蟲實作練習
#
#
# * 能夠利用 Request + BeatifulSour 撰寫爬蟲，並存放到合適的資料結構

# %% [markdown]
# ## 作業目標
#
# 根據範例 ，完成以下問題：
#
# * ① 印出最新文章的「作者」「標題」「時間」
# * ② 印出第一頁所有文章的「作者」「標題」「時間」

# %% [markdown]
# ### ① 印出最新文章的「作者」「標題」「時間」

# %%
import requests
from bs4 import BeautifulSoup

def assign_to_dict(dict_object, key, value):
    dict_object[key] = value.replace("\n", "").replace("\t", "")

url = 'https://www.ptt.cc/bbs/NBA/index.html'
rg = requests.get(url)

soup = BeautifulSoup(rg.text, "html5lib")

#print(soup.prettify())

for recent_post in soup.find_all("div", class_ = "r-ent"):
    temp_dict = {}
    
    for data in recent_post.find_all("div"):
        if ("author" in data.get("class")):
            assign_to_dict(temp_dict, "作者", data.text)
        
        if ("title" in data.get("class")):
            assign_to_dict(temp_dict, "標題", data.text)
            
        if ("date" in data.get("class")):
            assign_to_dict(temp_dict, "時間", data.text)
            
    for key, value in temp_dict.items():
        print (key, " : ", value)
        
    print()
# Out:
# 標題  :  (本文已被刪除) [dragon803]
# 作者  :  -
# 時間  :   3/15
#
# 標題  :  (本文已被刪除) [currykukuo]
# 作者  :  -
# 時間  :   3/15
#
# 標題  :  [花邊] 轉發席佛對球迷公開信 詹皇：已經開始想
# 作者  :  sodistrues
# 時間  :   3/15
#
# 標題  :  [新聞] 太陽獨行俠2K線上對決 唐西奇豪取50分
# 作者  :  currykukuo
# 時間  :   3/15
#
# 標題  :  [公告] 板規v6.8
# 作者  :  Vedan
# 時間  :   5/24
#
# 標題  :  [公告] 版主上任相關事項
# 作者  :  qazwsx879345
# 時間  :  10/25
#
# 標題  :  [情報] SEASON Schedule 賽程 March 19–20
# 作者  :  Acetoxy
# 時間  :   3/02
#
# 標題  :  [公告] 第一次被退文，可在三天後刪除退文
# 作者  :  Vedan
# 時間  :   3/09
#
# 標題  :  [公告]大怒灌
# 作者  :  namie810303
# 時間  :   3/12

# %% [markdown]
# ### ② 印出第一頁所有文章的「作者」「標題」「時間」

# %%
import requests
from bs4 import BeautifulSoup

def assign_to_dict(dict_object, key, value):
    dict_object[key] = value.replace("\n", "").replace("\t", "")

url = 'https://www.ptt.cc/bbs/NBA/index1.html'
rg = requests.get(url)

soup = BeautifulSoup(rg.text, "html5lib")

#print(soup.prettify())

for recent_post in soup.find_all("div", class_ = "r-ent"):
    temp_dict = {}
    
    for data in recent_post.find_all("div"):
        if ("author" in data.get("class")):
            assign_to_dict(temp_dict, "作者", data.text)
        
        if ("title" in data.get("class")):
            assign_to_dict(temp_dict, "標題", data.text)
            
        if ("date" in data.get("class")):
            assign_to_dict(temp_dict, "時間", data.text)
            
    for key, value in temp_dict.items():
        print (key, " : ", value)
        
    print()
# Out:
# 標題  :  [轉錄]Lyotard 對於太陽板討論串的結論
# 作者  :  Price
# 時間  :   5/16
#
# 標題  :  [公告] 請停止一切關於本次活動的發言
# 作者  :  Price
# 時間  :   5/31
#
# 標題  :  [轉錄]跟之前那篇比起來 我覺得這篇也應該轉過來
# 作者  :  Frankaze
# 時間  :   6/08
#
# 標題  :  [轉錄]再轉一篇好文來
# 作者  :  Frankaze
# 時間  :   6/08
#
# 標題  :  [轉錄][情報] 夏洛特山貓系列
# 作者  :  Price
# 時間  :   6/10
#
# 標題  :  [轉錄]Re: [心得] 真是受不了糗爺....
# 作者  :  Price
# 時間  :   6/10
#
# 標題  :  [轉錄]總冠軍賽NO.2觀後感
# 作者  :  Price
# 時間  :   6/10
#
# 標題  :  [心得] Rasheed Wallace
# 作者  :  AmuroNamie
# 時間  :   6/11
#
# 標題  :  掌控球賽的男人
# 作者  :  toptree
# 時間  :   6/12
#
# 標題  :  [閒聊] 說說2004季後賽名場面回顧
# 作者  :  skchang
# 時間  :   6/12
#
# 標題  :  [心得] 其實說穿了 就是活塞的防守太可怕了
# 作者  :  shineup
# 時間  :   6/12
#
# 標題  :  Re: [閒聊] 說說2004季後賽名場面回顧
# 作者  :  cOvi
# 時間  :   6/12
#
# 標題  :  Re: [閒聊] 說說2004季後賽名場面回顧
# 作者  :  ykshih
# 時間  :   6/12
#
# 標題  :  Re: [閒聊] 說說2004季後賽名場面回顧
# 作者  :  Frankaze
# 時間  :   6/12
#
# 標題  :  [轉錄]Re: 總冠軍賽NO.3觀後感
# 作者  :  Price
# 時間  :   6/14
#
# 標題  :  [轉錄]Re: 總冠軍賽NO.3觀後感
# 作者  :  Frankaze
# 時間  :   6/14
#
# 標題  :  Re: [轉錄]Re: 總冠軍賽NO.3觀後感
# 作者  :  star1
# 時間  :   6/14
#
# 標題  :  Re: [轉錄]Re: 總冠軍賽NO.3觀後感
# 作者  :  coldspring
# 時間  :   6/14
#
# 標題  :  Re: Kobe is frustrated...
# 作者  :  airbear
# 時間  :   6/14
#
# 標題  :  Re: [轉錄]Re: 總冠軍賽NO.3觀後感
# 作者  :  pennykidd
# 時間  :   6/14

# %% [markdown]
# ### ③ 試著爬爬看其他版的文章

# %%
import requests
from bs4 import BeautifulSoup

def assign_to_dict(dict_object, key, value):
    dict_object[key] = value.replace("\n", "").replace("\t", "")

url = 'https://www.ptt.cc/bbs/LoL/index.html'
rg = requests.get(url)

soup = BeautifulSoup(rg.text, "html5lib")

#print(soup.prettify())

for recent_post in soup.find_all("div", class_ = "r-ent"):
    temp_dict = {}
    
    for data in recent_post.find_all("div"):
        if ("author" in data.get("class")):
            assign_to_dict(temp_dict, "作者", data.text)
        
        if ("title" in data.get("class")):
            assign_to_dict(temp_dict, "標題", data.text)
            
        if ("date" in data.get("class")):
            assign_to_dict(temp_dict, "時間", data.text)
            
    for key, value in temp_dict.items():
        print (key, " : ", value)
        
    print()
# Out:
# 標題  :  [問題] 為什麼悟空上不了T1角
# 作者  :  myIDis7
# 時間  :   3/15
#
# 標題  :  Re: [閒聊] 從The shy身上 看見史丹利
# 作者  :  RainyCity
# 時間  :   3/15
#
# 標題  :  [揪團]  ar歡樂 隨便打 (休息啦
# 作者  :  lishen16
# 時間  :   3/15
#
# 標題  :  [情報] 《英雄聯盟》費德提克 英雄重製遊戲展示
# 作者  :  qwer338859
# 時間  :   3/15
#
# 標題  :  [情報] PCS菲律賓戰隊LYB跟RSG比賽延到今天四點
# 作者  :  joanzkow
# 時間  :   3/15
#
# 標題  :  [情報] 費德提克重製 技能
# 作者  :  LPCbaimlly
# 時間  :   3/15
#
# 標題  :  [情報] 費德提克 全造型重製美術圖
# 作者  :  S890127
# 時間  :   3/15
#
# 標題  :  [實況] 超負荷
# 作者  :  qwaszx012
# 時間  :   3/15
#
# 標題  :  [實況] FW NL/LeopoldyN/MKouo
# 作者  :  FeiChinzz
# 時間  :   3/15
#
# 標題  :  (本文已被刪除) [joywilliamjo]
# 作者  :  -
# 時間  :   3/15
#
# 標題  :  [閒聊] 為什麼打BO3都會遇到一堆憨皮啊
# 作者  :  tigotigo5566
# 時間  :   3/15
#
# 標題  :  [揪團] ARAM-4
# 作者  :  acerbic
# 時間  :   3/15
#
# 標題  :  [公告] 伺服器狀況詢問/聊天/揪團/抱怨/多功能區
# 作者  :  InnGee
# 時間  :   9/22
#
# 標題  :  [公告] LoL 英雄聯盟板板規（Patch 19.10.02）
# 作者  :  samhou6
# 時間  :   6/30
#
# 標題  :  [情報] PCS 2020 Spring 賽程表
# 作者  :  S890127
# 時間  :   2/21
#
# 標題  :  [電競] 2020 LPL Spring W2D6
# 作者  :  dinter9921
# 時間  :   3/14
#
# 標題  :  [電競] 2020 PCS Spring W3D2
# 作者  :  AOB123
# 時間  :   3/14
